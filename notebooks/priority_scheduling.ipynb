# %%
import seaborn as sns
import numpy as np
import pandas as pd

# %%
np.random.seed(0)
n = 20
x = np.random.random(n) * 100
y = np.random.random(n) * 100
g = sns.scatterplot(x='x', y='y', data=df, s = 100)

# %%
df = pd.DataFrame({'x': x, 'y': y})
df['path'] = df.index
path = [0, 3, 11, 2, 12, 9, 15, 16, 14, 4, 6, 10, 8, 13, 19, 17, 5, 1, 18, 7]
df_path = pd.DataFrame({'path':path})
df = df_path.merge(df,how = 'left', on = 'path')
g = sns.relplot(x='x', y='y',sort=False,kind = 'line', data=df , height = 6, aspect=1.5)

# %%
path = [0, 5, 10, 8, 13, 7, 18, 3, 11, 1, 19, 17, 2, 12, 9, 15, 16, 14, 4, 6]
df = pd.DataFrame({'x': x, 'y': y})
df['path'] = df.index
df_path = pd.DataFrame({'path':path})
df = df_path.merge(df,how = 'left', on = 'path')
g = sns.relplot(x='x', y='y',sort=False,kind = 'line', data=df , height = 6, aspect=1.5)
